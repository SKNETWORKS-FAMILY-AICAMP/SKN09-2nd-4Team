# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/Preprocessed_Bank_Customer_Churn_Prediction.csv')

# # 사용할 피처 선택 (customer_id 제거)
# features = ['credit_score', 'gender','age', 'tenure', 'balance', 'products_number', 'credit_card', 'active_member', 'estimated_salary']

df.head()
# Out:
#    credit_score  country  gender  age  tenure    balance  products_number  \
# 0           619        0       1   42       2       0.00                1
# 1           608        2       1   41       1   83807.86                1
# 2           502        0       1   42       8  159660.80                3
# 3           699        0       1   39       1       0.00                2
# 4           850        2       1   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %%
from sklearn.metrics import roc_curve, auc

def auc_plot(model, X_test, y_test):
    y_pred = model.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.4f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
# log1p 변환 수행
skewed_columns = ['age', 'balance', 'estimated_salary', 'credit_score']

for column in skewed_columns:
    df[column] = df[column].apply(np.log1p)
    
df.head()
# Out:
#    credit_score  country  gender       age  tenure    balance  \
# 0      6.429719        0       1  3.761200       2   0.000000
# 1      6.411818        2       1  3.737670       1  11.336294
# 2      6.220590        0       1  3.761200       8  11.980813
# 3      6.551080        0       1  3.688879       1   0.000000
# 4      6.746412        2       1  3.784190       2  11.740155
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         11.526334      1
# 1                1            0              1         11.631096      0
# 2                3            1              0         11.643362      1
# 3                2            0              0         11.449215      0
# 4                1            1              1         11.278280      0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 정규화 (Normalization) - 0과 1 사이로 변환
scaler = StandardScaler()

X = df.drop('churn', axis=1) 
# X = df.drop('ch')
print(X.head)
y = df['churn']

X = scaler.fit_transform(X)

# 학습 데이터와 테스트 데이터로 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
# Out:
# <bound method NDFrame.head of       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619        0       1   42       2       0.00                1
# 1              608        2       1   41       1   83807.86                1
# 2              502        0       1   42       8  159660.80                3
# 3              699        0       1   39       1       0.00                2
# 4              850        2       1   43       2  125510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9995           771        0       0   39       5       0.00                2
# 9996           516        0       0   35      10   57369.61                1
# 9997           709        0       1   36       7       0.00                1
# 9998           772        1       0   42       3   75075.31                2
# 9999           792        0       1   28       4  130142.79                1
#
#       credit_card  active_member  estimated_salary
# 0               1              1         101348.88
# 1               0              1         112542.58
# 2               1              0         113931.57
# 3               0              0          93826.63
# 4               1              1          79084.10
# ...           ...            ...               ...
# 9995            1              0          96270.64
# 9996            1              1         101699.77
# 9997            0              1          42085.58
# 9998            1              0          92888.52
# 9999            1              0          38190.78
#
# [10000 rows x 10 columns]>

# %%
import pandas as pd
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import numpy as np
import optuna
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, roc_curve, precision_recall_curve
# from catboost import CatBoostClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.ensemble import AdaBoostClassifier


# 학습 및 테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# 🎯 **하이퍼파라미터 최적화 (Optuna)**
def objective(trial):
    params = {
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 3),  # 이탈 고객 비율 증가
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'use_label_encoder': False,
        'random_state': 42
    }
    
    # 모델 학습
    model = XGBClassifier(**params)
    model.fit(X_train, y_train)

    # 예측 확률
    y_probs = model.predict_proba(X_test)[:, 1]

    # AUC 평가 기준
    return roc_auc_score(y_test, y_probs)

# **Optuna 실행**
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)

study.best_params
# Out:
# [I 2025-02-12 18:48:19,814] A new study created in memory with name: no-name-5a341566-721b-4384-9866-948c9c214e8b
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:19,987] Trial 0 finished with value: 0.8168748060361216 and parameters: {'colsample_bytree': 0.7111124337300033, 'learning_rate': 0.19701109071715955, 'max_depth': 6, 'min_child_weight': 3, 'n_estimators': 304, 'subsample': 0.6832548430286254, 'scale_pos_weight': 1.5688315781052269}. Best is trial 0 with value: 0.8168748060361216.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:20,103] Trial 1 finished with value: 0.8375348278628383 and parameters: {'colsample_bytree': 0.6670299663878478, 'learning_rate': 0.20023462849069346, 'max_depth': 4, 'min_child_weight': 9, 'n_estimators': 294, 'subsample': 0.8748873868998508, 'scale_pos_weight': 1.1442223482598934}. Best is trial 1 with value: 0.8375348278628383.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:20,326] Trial 2 finished with value: 0.8228932525575828 and parameters: {'colsample_bytree': 0.5041531085613227, 'learning_rate': 0.17351781468577324, 'max_depth': 5, 'min_child_weight': 3, 'n_estimators': 478, 'subsample': 0.6680250966859704, 'scale_pos_weight': 2.239991268996871}. Best is trial 1 with value: 0.8375348278628383.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:20,419] Trial 3 finished with value: 0.832564557001916 and parameters: {'colsample_bytree': 0.8465116670885042, 'learning_rate': 0.1691573505781343, 'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 123, 'subsample': 0.8477983696356133, 'scale_pos_weight': 1.638028514734573}. Best is trial 1 with value: 0.8375348278628383.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:20,482] Trial 4 finished with value: 0.8470636352239089 and parameters: {'colsample_bytree': 0.9774598862090534, 'learning_rate': 0.26575992066349413, 'max_depth': 3, 'min_child_weight': 10, 'n_estimators': 200, 'subsample': 0.8946666445985989, 'scale_pos_weight': 1.5193408058435558}. Best is trial 4 with value: 0.8470636352239089.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:20,618] Trial 5 finished with value: 0.8505602944208966 and parameters: {'colsample_bytree': 0.5301069025854581, 'learning_rate': 0.08340598341699156, 'max_depth': 6, 'min_child_weight': 6, 'n_estimators': 285, 'subsample': 0.9754805829687824, 'scale_pos_weight': 1.6390714574099874}. Best is trial 5 with value: 0.8505602944208966.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:20,676] Trial 6 finished with value: 0.8457592388463492 and parameters: {'colsample_bytree': 0.7902374462313995, 'learning_rate': 0.2551630495207829, 'max_depth': 4, 'min_child_weight': 9, 'n_estimators': 124, 'subsample': 0.7492271026370128, 'scale_pos_weight': 1.0165970788580836}. Best is trial 5 with value: 0.8505602944208966.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:20,795] Trial 7 finished with value: 0.8262323428644243 and parameters: {'colsample_bytree': 0.8087969186833885, 'learning_rate': 0.23071365757674805, 'max_depth': 5, 'min_child_weight': 8, 'n_estimators': 270, 'subsample': 0.8090082707977535, 'scale_pos_weight': 2.1187190330222827}. Best is trial 5 with value: 0.8505602944208966.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:21,256] Trial 8 finished with value: 0.8554874051075613 and parameters: {'colsample_bytree': 0.7180833768332904, 'learning_rate': 0.016036939551597542, 'max_depth': 10, 'min_child_weight': 2, 'n_estimators': 361, 'subsample': 0.8457055699622935, 'scale_pos_weight': 1.5410068938114625}. Best is trial 8 with value: 0.8554874051075613.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:21,598] Trial 9 finished with value: 0.8284602299546682 and parameters: {'colsample_bytree': 0.838580678581768, 'learning_rate': 0.06952359028006588, 'max_depth': 8, 'min_child_weight': 9, 'n_estimators': 458, 'subsample': 0.5297815074354575, 'scale_pos_weight': 2.828416649060755}. Best is trial 8 with value: 0.8554874051075613.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:22,156] Trial 10 finished with value: 0.8509802497672433 and parameters: {'colsample_bytree': 0.6551718782505251, 'learning_rate': 0.017881596123687723, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 387, 'subsample': 0.9706047586537927, 'scale_pos_weight': 2.6418727525967283}. Best is trial 8 with value: 0.8554874051075613.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:22,780] Trial 11 finished with value: 0.8518324919382959 and parameters: {'colsample_bytree': 0.6237263725288512, 'learning_rate': 0.01591061134141636, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 398, 'subsample': 0.9743150708659282, 'scale_pos_weight': 2.733272668194602}. Best is trial 8 with value: 0.8554874051075613.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:23,346] Trial 12 finished with value: 0.8573939886783326 and parameters: {'colsample_bytree': 0.604915021092159, 'learning_rate': 0.01131159727742509, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 391, 'subsample': 0.9348374904602136, 'scale_pos_weight': 2.448414492070408}. Best is trial 12 with value: 0.8573939886783326.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:23,710] Trial 13 finished with value: 0.8293974223099737 and parameters: {'colsample_bytree': 0.5783915859095426, 'learning_rate': 0.09768008038249754, 'max_depth': 9, 'min_child_weight': 4, 'n_estimators': 372, 'subsample': 0.7671137141228481, 'scale_pos_weight': 2.3975921357924115}. Best is trial 12 with value: 0.8573939886783326.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:24,034] Trial 14 finished with value: 0.8246230849385379 and parameters: {'colsample_bytree': 0.7085290644557565, 'learning_rate': 0.11817598969963974, 'max_depth': 9, 'min_child_weight': 5, 'n_estimators': 349, 'subsample': 0.9114409280053152, 'scale_pos_weight': 1.9279239036965308}. Best is trial 12 with value: 0.8573939886783326.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:24,391] Trial 15 finished with value: 0.8349280903541121 and parameters: {'colsample_bytree': 0.9103809156411132, 'learning_rate': 0.04544607644630566, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 412, 'subsample': 0.811867331781184, 'scale_pos_weight': 1.8887870674046778}. Best is trial 12 with value: 0.8573939886783326.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:24,773] Trial 16 finished with value: 0.8195130573228772 and parameters: {'colsample_bytree': 0.577110675859875, 'learning_rate': 0.12881987711624693, 'max_depth': 10, 'min_child_weight': 6, 'n_estimators': 429, 'subsample': 0.9214508580398484, 'scale_pos_weight': 2.4325107420103502}. Best is trial 12 with value: 0.8573939886783326.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:25,006] Trial 17 finished with value: 0.84283736355733 and parameters: {'colsample_bytree': 0.7554614556583734, 'learning_rate': 0.05367031303527019, 'max_depth': 9, 'min_child_weight': 2, 'n_estimators': 222, 'subsample': 0.5172633728875732, 'scale_pos_weight': 1.2928866784444928}. Best is trial 12 with value: 0.8573939886783326.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:25,294] Trial 18 finished with value: 0.8532266340750261 and parameters: {'colsample_bytree': 0.6166976754626563, 'learning_rate': 0.030399983353633427, 'max_depth': 8, 'min_child_weight': 4, 'n_estimators': 336, 'subsample': 0.6883896342463589, 'scale_pos_weight': 2.500196265800474}. Best is trial 12 with value: 0.8573939886783326.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:25,652] Trial 19 finished with value: 0.820252260942303 and parameters: {'colsample_bytree': 0.7305940822220353, 'learning_rate': 0.12119849064045173, 'max_depth': 7, 'min_child_weight': 2, 'n_estimators': 492, 'subsample': 0.8449631095873247, 'scale_pos_weight': 2.976156852148951}. Best is trial 12 with value: 0.8573939886783326.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:25,963] Trial 20 finished with value: 0.8453605210460656 and parameters: {'colsample_bytree': 0.5509662034884668, 'learning_rate': 0.05537850556069508, 'max_depth': 9, 'min_child_weight': 5, 'n_estimators': 346, 'subsample': 0.9384390678095922, 'scale_pos_weight': 1.3501761898720241}. Best is trial 12 with value: 0.8573939886783326.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:26,313] Trial 21 finished with value: 0.8633377612475072 and parameters: {'colsample_bytree': 0.6313740245152052, 'learning_rate': 0.011859282294101353, 'max_depth': 8, 'min_child_weight': 4, 'n_estimators': 356, 'subsample': 0.6681645724881239, 'scale_pos_weight': 2.5195061980699727}. Best is trial 21 with value: 0.8633377612475072.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:26,809] Trial 22 finished with value: 0.8549044002140196 and parameters: {'colsample_bytree': 0.6815727519569544, 'learning_rate': 0.01619439427468023, 'max_depth': 10, 'min_child_weight': 4, 'n_estimators': 438, 'subsample': 0.5858930171105962, 'scale_pos_weight': 2.2117196906367607}. Best is trial 21 with value: 0.8633377612475072.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:27,135] Trial 23 finished with value: 0.8465813374036347 and parameters: {'colsample_bytree': 0.6204289807137169, 'learning_rate': 0.04754632501103882, 'max_depth': 8, 'min_child_weight': 2, 'n_estimators': 334, 'subsample': 0.60154199702825, 'scale_pos_weight': 1.811167662957987}. Best is trial 21 with value: 0.8633377612475072.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:27,363] Trial 24 finished with value: 0.836754519315548 and parameters: {'colsample_bytree': 0.6451438428452757, 'learning_rate': 0.08473497151807095, 'max_depth': 9, 'min_child_weight': 7, 'n_estimators': 237, 'subsample': 0.7340594166837732, 'scale_pos_weight': 2.6348249434432}. Best is trial 21 with value: 0.8633377612475072.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:27,863] Trial 25 finished with value: 0.8603788915234103 and parameters: {'colsample_bytree': 0.7615999500396038, 'learning_rate': 0.010303347607512458, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 375, 'subsample': 0.629392152378925, 'scale_pos_weight': 2.0854236026118227}. Best is trial 21 with value: 0.8633377612475072.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:28,131] Trial 26 finished with value: 0.8545180138920955 and parameters: {'colsample_bytree': 0.5949752985871416, 'learning_rate': 0.04063551369002314, 'max_depth': 7, 'min_child_weight': 4, 'n_estimators': 314, 'subsample': 0.6225892553792098, 'scale_pos_weight': 2.0693826827726953}. Best is trial 21 with value: 0.8633377612475072.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:28,514] Trial 27 finished with value: 0.832169264612288 and parameters: {'colsample_bytree': 0.7496578479511091, 'learning_rate': 0.06762386219715982, 'max_depth': 9, 'min_child_weight': 5, 'n_estimators': 406, 'subsample': 0.6427776274610028, 'scale_pos_weight': 2.330677822542939}. Best is trial 21 with value: 0.8633377612475072.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:28,964] Trial 28 finished with value: 0.7998559957360488 and parameters: {'colsample_bytree': 0.7855819186340385, 'learning_rate': 0.28575481844391093, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 452, 'subsample': 0.5503442798654892, 'scale_pos_weight': 2.55275590226205}. Best is trial 21 with value: 0.8633377612475072.
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:48:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-12 18:48:29,310] Trial 29 finished with value: 0.8259939342828116 and parameters: {'colsample_bytree': 0.6904710282603159, 'learning_rate': 0.10101218462665063, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 380, 'subsample': 0.699865765281507, 'scale_pos_weight': 2.2689087036294726}. Best is trial 21 with value: 0.8633377612475072.
# {'colsample_bytree': 0.6313740245152052,
#  'learning_rate': 0.011859282294101353,
#  'max_depth': 8,
#  'min_child_weight': 4,
#  'n_estimators': 356,
#  'subsample': 0.6681645724881239,
#  'scale_pos_weight': 2.5195061980699727}

# %%
# %pip install catboost

# %%
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

ada_best_params = {
    'learning_rate': 1, 
    'n_estimators': 450
}

ada_best_params = {
    'n_estimators': 297, 
    'learning_rate': 0.29436353114378083
}

ada = AdaBoostClassifier(random_state=42, **ada_best_params)

cat_best_params = {
    'depth': 4, 
    'iterations': 100, 
    'learning_rate': 0.1
}
cat_best_params = {
    'iterations': 938,
    'depth': 4,
    'learning_rate': 0.04029667375026597,
    'random_strength': 62,
    'bagging_temperature': 1.0589520689603074,
    'od_type': 'Iter',
    'od_wait': 49,
    'l2_leaf_reg': 606.8679965211409,
    'border_count': 247
}
cat = CatBoostClassifier(random_state=42, **cat_best_params, verbose=0, class_weights=[1, 2.21])
# cat = CatBoostClassifier(random_state=42, **cat_best_params, verbose=0, class_weights=[1, 50])

xgb_best_params = {
'colsample_bytree': 0.998835926756326,
    'learning_rate': 0.05918736154295684,
    'max_depth': 4,
    'min_child_weight': 4,
    'n_estimators': 152,
    'subsample': 0.7171956369176462,
    'scale_pos_weight': 1.9,  # Recall 최적화된 비율
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
}
xgb = XGBClassifier(random_state=42, **xgb_best_params)

rf_best_params = {
    'n_estimators':200, 
    'max_depth':15, 
    'min_samples_leaf':2, 
    'min_samples_split':5
}
rf_best_params = {'n_estimators': 153,
    'max_depth': 6,
    'min_samples_split': 6,
    'min_samples_leaf': 2,
    'max_features': 3
}
rf = RandomForestClassifier(random_state=42, **rf_best_params, verbose=0)

# %%
# import optuna

# def objective(trial):
#     # AdaBoostClassifier
#     ada_params = {
#         'n_estimators': trial.suggest_int('n_estimators', 100, 500),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1)
#     }
#     ada = AdaBoostClassifier(random_state=42, **ada_params)
    
#     # CatBoostClassifier
#     cat_params = {
#         'depth': trial.suggest_int('depth', 4, 10),
#         'iterations': trial.suggest_int('iterations', 100, 500),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1)
#     }
#     cat = CatBoostClassifier(random_state=42, **cat_params, verbose=0, class_weights=[1, 2.21])
    
#     # XGBClassifier
#     xgb_params = {
#         'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.1, 1),
#         'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 1),
#         'max_depth': trial.suggest_int('max_depth', 3, 10),
#         'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
#         'n_estimators': trial.suggest_int('n_estimators', 100, 500),
#         'subsample': trial.suggest_uniform('subsample', 0.1, 1),
#         'scale_pos_weight': trial.suggest_uniform('scale_pos_weight', 1, 2),
#         'objective': 'binary:logistic',
#         'eval_metric': 'logloss'
#     }
#     xgb = XGBClassifier(random_state=42, **xgb_params)
    
#     # RandomForestClassifier
#     rf_params = {
#         'n_estimators': trial.suggest_int('n_estimators', 100, 500),
#         'max_depth': trial.suggest_int('max_depth', 3, 20),
#         'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
#         'min_samples_split': trial.suggest_int('min_samples_split', 2, 10)
#     }
#     rf = RandomForestClassifier(random_state=42, **rf_params, verbose=0)
    
#     models = [ada, cat, xgb, rf]
#     model_names = ['AdaBoost', 'CatBoost', 'XGBoost', 'RandomForest']
    
#     best_score = 0
    
#     for model, model_name in zip(models, model_names):
#         model.fit(X_train, y_train)
#         score = model.score(X_test, y_test)
        
#         if score > best_score:
#             best_score = score
            
#     return best_score

# study = optuna.create_study(direction='maximize')

# study.optimize(objective, n_trials=100)

# study.best_params

# study.best_value

# study.trials_dataframe()

# %%
from sklearn.metrics import classification_report

cat.fit(X_train, y_train)

# 모델 평가
y_pred = cat.predict(X_test)

print(classification_report(y_test, y_pred, digits=4))

auc_plot(cat, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9070    0.9025    0.9047      2389
#            1     0.6260    0.6383    0.6321       611
#
#     accuracy                         0.8487      3000
#    macro avg     0.7665    0.7704    0.7684      3000
# weighted avg     0.8498    0.8487    0.8492      3000

# %%
from sklearn.ensemble import VotingClassifier

estimators = [
    ('cat', cat),
    ('xgb', xgb),
    ('rf', rf),
    ('ada', ada)
]

voting = VotingClassifier(estimators=estimators, voting='soft')

voting.fit(X_train, y_train)

y_pred = voting.predict(X_test)

print(classification_report(y_test, y_pred, digits=4))

auc_plot(voting, X_test, y_test)
# Out:
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0     0.8911    0.9422    0.9160      2389
#            1     0.7089    0.5499    0.6194       611
#
#     accuracy                         0.8623      3000
#    macro avg     0.8000    0.7461    0.7677      3000
# weighted avg     0.8540    0.8623    0.8556      3000

# %%
from itertools import permutations
from sklearn.ensemble import StackingClassifier

perms = list(map(list, permutations(estimators)))

estimators = [
    ('rf', rf),
    ('xgb', xgb),
    ('ada', ada),
    ('cat', cat),
]

# for perm in perms:
stacking = StackingClassifier(estimators=estimators, final_estimator=cat, cv=5)

stacking.fit(X_train, y_train)

y_pred = stacking.predict(X_test)

print(classification_report(y_test, y_pred, digits=4))

auc_plot(stacking, X_test, y_test)
# Out:
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\anaconda3\envs\pystudy_env\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0     0.9086    0.8949    0.9017      2389
#            1     0.6121    0.6481    0.6296       611
#
#     accuracy                         0.8447      3000
#    macro avg     0.7603    0.7715    0.7656      3000
# weighted avg     0.8482    0.8447    0.8463      3000

# %%
from joblib import dump

dump(stacking, '../model/stacking.joblib')
# Out:
# ['../model/stacking.joblib']
